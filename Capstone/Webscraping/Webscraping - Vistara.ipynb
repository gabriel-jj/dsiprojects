# %%
# Import libaries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/vistara/?sortby=post_date%3ADesc&pagesize=100'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    try:
        for name, rating in zip(names[1:], ratings):
            review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    except:
        review_dict[name.text] = np.nan
    
    # Author, Date, Overall_rating,Text_content, Recommended
    review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
    review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
    review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
    review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    try:
        review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    
    except:
        review_dict['Overall_rating'] = np.nan
    
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df = pd.DataFrame(final_list)
df['airline'] = 'vistara'

# rearrange dataframe
df = df[['airline','Author','Date','text_content','traveller_type','seat_type','Overall_rating','Seat Comfort',
 'Cabin Staff Service','Food & Beverages','Inflight Entertainment','Ground Service','Value For Money',  
  'Recommended']]

# rename dataframe
df.columns = ['airline_name', 'author', 'date', 'content', 'type_traveller','cabin_flown', 'overall_rating', 'seat_comfort_rating',
'cabin_staff_rating', 'food_beverages_rating','inflight_entertainment_rating', 'ground_service_rating','value_money_rating', 'recommended']

# Save to CSV
#df.to_csv('Data/vistara.csv',index=False)

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/vistara/page/2/?sortby=post_date%3ADesc&pagesize=100'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    try:
        for name, rating in zip(names[1:], ratings):
            review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    except:
        review_dict[name.text] = np.nan
    
    # Author, Date, Overall_rating,Text_content, Recommended
    review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
    review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
    review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
    review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    try:
        review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    
    except:
        review_dict['Overall_rating'] = np.nan
    
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df2 = pd.DataFrame(final_list)
df2['airline'] = 'vistara'

# rearrange dataframe
df2 = df2[['airline','Author','Date','text_content','traveller_type','seat_type','Overall_rating','Seat Comfort',
 'Cabin Staff Service','Food & Beverages','Inflight Entertainment','Ground Service','Value For Money',  
  'Recommended']]

# rename dataframe
df2.columns = ['airline_name', 'author', 'date', 'content', 'type_traveller','cabin_flown', 'overall_rating', 'seat_comfort_rating',
'cabin_staff_rating', 'food_beverages_rating','inflight_entertainment_rating', 'ground_service_rating','value_money_rating', 'recommended']


# Merge df1 and df2
df_merged = pd.concat([df,df2],axis=0,join='outer')
df_merged.reset_index(level=0, inplace=True,drop=True)

# Save to CSV
df_merged.to_csv('Data/vistara.csv',index=False)

# %%
# Sanity check
df_merged.head()
# Out:
#   airline_name          author        date  \
# 0      vistara        H Barten  2020-04-16
# 1      vistara  Jonathan Rivas  2020-04-08
# 2      vistara       S Pardelo  2020-04-04
# 3      vistara  Dhondi Pradeep  2020-03-22
# 4      vistara         J Tovey  2020-03-15
#
#                                              content  type_traveller  \
# 0  ✅ Trip Verified |  Guwahati to Delhi. My fligh...  Couple Leisure
# 1  ✅ Trip Verified |  Me and my partner were rece...  Couple Leisure
# 2  ✅ Trip Verified |  Kochi to Delhi. The Airline...  Couple Leisure
# 3  ✅ Trip Verified |  Hyderabad to Delhi. Vistara...    Solo Leisure
# 4  Not Verified |  Delhi to Goa. Really pleasant ...  Couple Leisure
#
#      cabin_flown overall_rating seat_comfort_rating cabin_staff_rating  \
# 0  Economy Class              1                 NaN                NaN
# 1  Economy Class              1                 NaN                NaN
# 2  Economy Class              1                 NaN                NaN
# 3  Economy Class              1                 NaN                NaN
# 4  Economy Class             10                   5                  5
#
#   food_beverages_rating inflight_entertainment_rating ground_service_rating  \
# 0                   NaN                           NaN                   NaN
# 1                   NaN                           NaN                   NaN
# 2                   NaN                           NaN                   NaN
# 3                   NaN                           NaN                   NaN
# 4                     5                           NaN                     5
#
#   value_money_rating recommended
# 0                  1          no
# 1                  1          no
# 2                  1          no
# 3                  2          no
# 4                  5         yes

# %%
df_merged.tail()
# Out:
#     airline_name            author        date  \
# 117      vistara     Harsh Vardhan  2015-11-12
# 118      vistara  Yashasvi Makwana  2015-10-21
# 119      vistara     Sameer Phatak  2015-10-12
# 120      vistara       Shivam Negi  2015-09-26
# 121      vistara       Shivam Negi  2015-09-25
#
#                                                content  type_traveller  \
# 117  I flew Guwahati to Delhi return with Vistara i...  Couple Leisure
# 118  It was my first trip with Vistara. I had 9 kg ...        Business
# 119  Mumbai to Delhi with Vistara. My check in proc...    Solo Leisure
# 120  My third Vistara flight and using Premium Econ...    Solo Leisure
# 121  My flight on Vistara was the second day of ope...    Solo Leisure
#
#          cabin_flown overall_rating seat_comfort_rating cabin_staff_rating  \
# 117    Economy Class              8                   5                  4
# 118    Economy Class              8                   3                  3
# 119    Economy Class             10                   5                  5
# 120  Premium Economy             10                   5                  5
# 121    Economy Class              9                   5                  5
#
#     food_beverages_rating inflight_entertainment_rating ground_service_rating  \
# 117                     5                             2                     4
# 118                     4                           NaN                     4
# 119                     5                           NaN                     5
# 120                     4                           NaN                     5
# 121                     4                           NaN                     4
#
#     value_money_rating recommended
# 117                  5         yes
# 118                  4         yes
# 119                  5         yes
# 120                  5         yes
# 121                  4         yes
