# %%
# Import libaries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/adria-airways/?sortby=post_date%3ADesc&pagesize=20'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    for name, rating in zip(names[1:], ratings):
        review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    
    # Author, Date, Overall_rating,Text_content, Recommended
    review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
    review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
    review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
    review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df = pd.DataFrame(final_list)
df['airline'] = 'adria airways'

# rearrange dataframe
df = df[['airline','Author','Date','text_content','traveller_type','seat_type','Overall_rating','Seat Comfort',
 'Cabin Staff Service','Food & Beverages','Inflight Entertainment','Ground Service','Value For Money',  
  'Recommended']]

# rename dataframe
df.columns = ['airline_name', 'author', 'date', 'content', 'type_traveller','cabin_flown', 'overall_rating', 'seat_comfort_rating',
'cabin_staff_rating', 'food_beverages_rating','inflight_entertainment_rating', 'ground_service_rating','value_money_rating', 'recommended']

# Save to CSV
df.to_csv('Data/adria_airways.csv',index=False)

# %%
# Sanity check
df
# Out:
#      airline_name            author        date  \
# 0   adria airways    D Praetextatus  2019-09-28
# 1   adria airways          D Meijer  2019-09-24
# 2   adria airways      Herbse Mayer  2019-09-17
# 3   adria airways            D Bole  2019-09-06
# 4   adria airways         B Cosmin   2019-08-24
# 5   adria airways      Thomas Gloor  2019-08-06
# 6   adria airways           M Jager  2018-10-12
# 7   adria airways      Giulia Rossi  2018-10-05
# 8   adria airways      Galya Slavov  2018-07-29
# 9   adria airways        Loic Jouan  2018-07-19
# 10  adria airways          P Gamirj  2018-06-30
# 11  adria airways           B Haruz  2018-06-24
# 12  adria airways     Michel Zombra  2018-05-04
# 13  adria airways       S Hanarosic  2018-03-11
# 14  adria airways          P Gregan  2017-12-05
# 15  adria airways         G Vincent  2017-11-20
# 16  adria airways           A Kalen  2017-10-27
# 17  adria airways       J Marikovic  2017-09-16
# 18  adria airways   Alexander Stare  2017-04-19
# 19  adria airways  Andreas Hartlieb  2017-01-27
#
#                                               content  type_traveller  \
# 0   Not Verified |  Please do a favor yourself and...    Solo Leisure
# 1   ✅ Trip Verified | Do not book a flight with th...  Couple Leisure
# 2   ✅ Trip Verified |  Had very bad experience wit...  Couple Leisure
# 3   Not Verified |  Ljubljana to Zürich. Firstly, ...        Business
# 4   Not Verified |  First of all, I am not complai...    Solo Leisure
# 5   ✅ Trip Verified |  Worst Airline ever! They co...    Solo Leisure
# 6   ✅ Trip Verified | Ljubljana to Munich. The hom...  Family Leisure
# 7   Not Verified |  Zurich to Ljubljana. Very poor...        Business
# 8   ✅ Trip Verified |  Vienna to Sofia. The flight...  Family Leisure
# 9   ✅ Trip Verified |  We were traveling from Pari...    Solo Leisure
# 10  ✅ Trip Verified |  Ljubljana to Munich. Adria'...        Business
# 11  ✅ Trip Verified |  A very unpleasant experienc...  Couple Leisure
# 12  ✅ Trip Verified |  Frankfurt to Ljubljana. Fli...        Business
# 13  ✅ Trip Verified |  Ljubljana to Frankfurt. Fli...    Solo Leisure
# 14  ✅ Trip Verified |  Ljubljana to Vienna. Overal...    Solo Leisure
# 15  ✅ Trip Verified | Two nice short flights from ...        Business
# 16  ✅ Verified Review | We were 11 people coming i...  Couple Leisure
# 17  ✅ Verified Review |  Ljubljana to Munich after...  Family Leisure
# 18  ✅ Verified Review | Ljubljana to Zurich on Apr...        Business
# 19  ✅ Verified Review |  Ljubljana to Vienna. Afte...    Solo Leisure
#
#        cabin_flown overall_rating seat_comfort_rating cabin_staff_rating  \
# 0    Economy Class              1                   1                  1
# 1    Economy Class              1                   1                  1
# 2    Economy Class              1                   1                  1
# 3    Economy Class              1                   1                  1
# 4    Economy Class              1                   1                  1
# 5    Economy Class              1                   1                  2
# 6    Economy Class              8                   4                  4
# 7    Economy Class              1                   2                  1
# 8    Economy Class              1                   4                  1
# 9    Economy Class              2                   3                  3
# 10   Economy Class              2                   1                  2
# 11   Economy Class              3                   3                  3
# 12   Economy Class             10                   5                  5
# 13   Economy Class              1                   2                  1
# 14   Economy Class              3                   2                  4
# 15   Economy Class              9                   5                  5
# 16   Economy Class              2                   3                  3
# 17   Economy Class              2                   3                  4
# 18   Economy Class              9                   5                  5
# 19  Business Class              8                   5                  5
#
#    food_beverages_rating inflight_entertainment_rating ground_service_rating  \
# 0                    NaN                           NaN                     1
# 1                      1                             1                     1
# 2                      1                             1                     1
# 3                      1                           NaN                     1
# 4                      1                             1                     1
# 5                      1                             1                     1
# 6                      3                           NaN                     5
# 7                    NaN                             1                     1
# 8                      1                           NaN                     4
# 9                    NaN                           NaN                     3
# 10                     2                           NaN                     2
# 11                   NaN                           NaN                     1
# 12                     5                           NaN                     5
# 13                     1                             1                     1
# 14                     1                           NaN                     1
# 15                     3                           NaN                     5
# 16                   NaN                           NaN                     1
# 17                     1                           NaN                     1
# 18                     4                             4                     5
# 19                     4                             5                     5
#
#    value_money_rating recommended
# 0                   1          no
# 1                   1          no
# 2                   1          no
# 3                   1          no
# 4                   1          no
# 5                   1          no
# 6                   5         yes
# 7                   1          no
# 8                   1          no
# 9                   2          no
# 10                  1          no
# 11                  1          no
# 12                  5         yes
# 13                  1          no
# 14                  3          no
# 15                  3         yes
# 16                  1          no
# 17                  2          no
# 18                  4         yes
# 19                  4         yes

# %%
df.columns
# Out:
# Index(['airline_name', 'author', 'date', 'content', 'type_traveller',
#        'cabin_flown', 'overall_rating', 'seat_comfort_rating',
#        'cabin_staff_rating', 'food_beverages_rating',
#        'inflight_entertainment_rating', 'ground_service_rating',
#        'value_money_rating', 'recommended'],
#       dtype='object')
