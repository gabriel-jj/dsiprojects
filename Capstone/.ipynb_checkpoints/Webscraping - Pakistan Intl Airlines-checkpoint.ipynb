# %%
# Import libaries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/pia-pakistan-international-airlines/?sortby=post_date%3ADesc&pagesize=100'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    try:
        for name, rating in zip(names[1:], ratings):
            review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    except:
        review_dict[name.text] = np.nan
    
    # Author, Date, Overall_rating,Text_content, Recommended
    try:
        review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
        review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
        review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
        review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
    
    except:
        review_dict['Overall_rating'] = np.nan
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    # Overall Rating
    try:
        review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    
    except:
        review_dict['Overall_rating'] = np.nan
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df = pd.DataFrame(final_list)
df['airline'] = 'pakistan intl airlines'

# Save to CSV
df.to_csv('Data/pakistan.csv',index=False)

# %%
# Sanity check
df.tail(8)
# Out:
#    Value For Money Ground Service Food & Beverages Cabin Staff Service  \
# 92               5            NaN                4                   5
# 93               5            NaN                4                   5
# 94               5            NaN                5                   5
# 95               3            NaN                4                   5
# 96               4            NaN                5                   5
# 97               2            NaN                1                   4
# 98               3            NaN                5                   5
# 99               3            NaN                5                   5
#
#    Seat Comfort         Author        Date  \
# 92            5        M Aftab  2014-01-13
# 93            4  Yazdani Usman  2013-12-20
# 94            5      Muzzy Ali  2013-12-12
# 95            4  Huzayfah Alam  2013-12-11
# 96            4       R Edward  2013-12-10
# 97            3        R Iqbal  2013-12-09
# 98            4   Altaf Ayesha  2013-12-04
# 99            4  Mohammad Asif  2013-10-20
#
#                                          text_content Recommended  \
# 92  PK788 from London-Heathrow (LHR) to Karachi (K...         yes
# 93  Travelled from Peshawar to Karachi and back. T...         yes
# 94  Went on fairly new B777-300er plane straight f...         yes
# 95  We were flying from Lahore Punjab Pakistan to ...         yes
# 96  Travelled PIA for the first time (LHR-ISB PK78...         yes
# 97  London Heathrow to Lahore Pakistan PK758 2 Nov...          no
# 98  Been using PIA for several years. Mainly becau...          no
# 99  Flew from Multan-Jeddah on PK-731. Basically i...         yes
#
#    traveller_type        seat_type Overall_rating Wifi & Connectivity  \
# 92            NaN    Economy Class            NaN                 NaN
# 93            NaN    Economy Class            NaN                 NaN
# 94            NaN    Economy Class            NaN                 NaN
# 95            NaN    Economy Class            NaN                 NaN
# 96            NaN    Economy Class            NaN                 NaN
# 97            NaN    Economy Class            NaN                 NaN
# 98            NaN    Economy Class            NaN                 NaN
# 99            NaN  Premium Economy            NaN                 NaN
#
#    Inflight Entertainment                 airline
# 92                      4  pakistan intl airlines
# 93                      3  pakistan intl airlines
# 94                      5  pakistan intl airlines
# 95                      3  pakistan intl airlines
# 96                      3  pakistan intl airlines
# 97                      1  pakistan intl airlines
# 98                      3  pakistan intl airlines
# 99                      2  pakistan intl airlines

# %%
df.head()
# Out:
#   Value For Money Ground Service Food & Beverages Cabin Staff Service  \
# 0               1              1                1                   1
# 1               1            NaN              NaN                 NaN
# 2               2              3                3                   3
# 3               1              1                3                   1
# 4               1              1                3                   5
#
#   Seat Comfort          Author        Date  \
# 0            1        A Sarqir  2020-06-04
# 1          NaN        L Malban  2020-03-27
# 2            2          A Khan  2020-03-14
# 3            1          J Khan  2020-02-24
# 4            3  Niknam Hussain  2020-02-08
#
#                                         text_content Recommended  \
# 0  ✅ Trip Verified |  I will never use this airli...          no
# 1  ✅ Trip Verified |  Birmingham to Islamabad. I ...          no
# 2  ✅ Trip Verified |  Flew executive economy from...          no
# 3  Not Verified |  Manchester to Lahore. I went w...          no
# 4  ✅ Trip Verified |  Birmingham to Islamabad. Tr...          no
#
#    traveller_type        seat_type Overall_rating Wifi & Connectivity  \
# 0  Family Leisure    Economy Class              1                 NaN
# 1    Solo Leisure    Economy Class              1                 NaN
# 2    Solo Leisure  Premium Economy              3                   1
# 3  Family Leisure    Economy Class              1                 NaN
# 4  Family Leisure  Premium Economy              3                 NaN
#
#   Inflight Entertainment                 airline
# 0                    NaN  pakistan intl airlines
# 1                    NaN  pakistan intl airlines
# 2                      1  pakistan intl airlines
# 3                    NaN  pakistan intl airlines
# 4                    NaN  pakistan intl airlines
