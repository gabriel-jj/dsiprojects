# %%
# Import libaries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/privilege-style/?sortby=post_date%3ADesc&pagesize=20'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    try:
        for name, rating in zip(names[1:], ratings):
            review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    except:
        review_dict[name.text] = np.nan
    
    # Author, Date, Overall_rating,Text_content, Recommended
    review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
    review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
    review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
    review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df = pd.DataFrame(final_list)
df['airline'] = 'privilege style'

# Save to CSV
df.to_csv('Data/privilege_style.csv',index=False)

# %%
# Sanity check
df.tail()
# Out:
#    Value For Money Ground Service Food & Beverages Cabin Staff Service  \
# 8                1              1                1                   3
# 9                1              1                3                   3
# 10               1              2                2                   1
# 11               3              5                2                   5
# 12               5              1                5                   5
#
#    Seat Comfort                  Author        Date Overall_rating  \
# 8             1  Fernando Marco Liguori  2018-11-26              1
# 9             1                P Lesuno  2018-09-19              2
# 10            1            Laura Rooney  2018-09-05              2
# 11            2             Silvia Tisi  2018-02-10              7
# 12            3               S Gressen  2017-02-16              9
#
#                                          text_content Recommended  \
# 8   ✅ Trip Verified |  Rome to Newark. This is the...          no
# 9   ✅ Trip Verified |  Norwegian notified us that ...          no
# 10  Not Verified |  Very disappointed in this Norw...          no
# 11  ✅ Trip Verified | Flew Zanzibar to Milan with ...         yes
# 12  ✅ Verified Review |  Montego Bay to Munich wit...         yes
#
#     traveller_type        seat_type Wifi & Connectivity  \
# 8     Solo Leisure    Economy Class                   1
# 9   Couple Leisure  Premium Economy                 NaN
# 10    Solo Leisure    Economy Class                   2
# 11  Couple Leisure    Economy Class                 NaN
# 12  Couple Leisure    Economy Class                 NaN
#
#    Inflight Entertainment          airline
# 8                       1  privilege style
# 9                       1  privilege style
# 10                      1  privilege style
# 11                      1  privilege style
# 12                    NaN  privilege style

# %%
df.head()
# Out:
#   Value For Money Ground Service Food & Beverages Cabin Staff Service  \
# 0               5              3                3                   3
# 1               5              3                3                   3
# 2               5              5                5                   5
# 3               3              3                1                   4
# 4               5              4                5                   5
#
#   Seat Comfort            Author        Date Overall_rating  \
# 0            3      Ndulue Yauri  2020-01-28              5
# 1            3      Abdal Ghafar  2020-01-25              5
# 2            5  Robert Dullighan  2019-09-29             10
# 3            3          B Carson  2019-08-17              6
# 4            4    Nicole Gunning  2019-07-30              9
#
#                                         text_content Recommended  \
# 0  ✅ Trip Verified |  Vienna to Lagos. The flight...          no
# 1  ✅ Trip Verified |  Munich to Kabul. Privilege ...          no
# 2  Not Verified |  CAA replacement for Thomas Coo...         yes
# 3  ✅ Trip Verified |  Manchester to Tenerife. On ...         yes
# 4  Not Verified |  Manchester to Lanzorote. We bo...         yes
#
#    traveller_type      seat_type Wifi & Connectivity Inflight Entertainment  \
# 0    Solo Leisure  Economy Class                 NaN                    NaN
# 1    Solo Leisure  Economy Class                   3                      3
# 2  Family Leisure  Economy Class                 NaN                    NaN
# 3  Family Leisure  Economy Class                 NaN                    NaN
# 4  Family Leisure  Economy Class                 NaN                    NaN
#
#            airline
# 0  privilege style
# 1  privilege style
# 2  privilege style
# 3  privilege style
# 4  privilege style
