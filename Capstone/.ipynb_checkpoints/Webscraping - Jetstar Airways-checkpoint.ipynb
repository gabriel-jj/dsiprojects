# %%
# Import libaries

from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
final_list = []

# Skytrax URL
url = 'https://www.airlinequality.com/airline-reviews/jetstar-airways/?sortby=post_date%3ADesc&pagesize=100'

# Request URL
response = requests.get(url)

# Create Soup
soup = BeautifulSoup(response.content, 'lxml')

# For loop for HTML
for idx, review in enumerate(soup.find_all('div',{'class':"review-stats"})):
    
    # Create a empty dictionary to contain columns and values
    review_dict = dict()
    
    # Values that is in star fill
    names = review.find_all('td', class_='review-rating-header')[::-1]
    ratings = review.find_all('td', class_='stars')[::-1]
    
    for name, rating in zip(names[1:], ratings):
        review_dict[name.text] = rating.find_all(class_='fill')[-1].text
    
    # Author, Date, Overall_rating,Text_content, Recommended
    review_dict['Author'] = soup.find_all(itemprop='name')[idx+1].text
    review_dict['Date'] = soup.find_all(itemprop='datePublished')[::2][idx].attrs['content']
    review_dict['Overall_rating'] = soup.find_all('div',{'itemprop':'reviewRating'})[idx].find(itemprop="ratingValue").text
    review_dict['text_content'] = soup.find_all('div',class_='text_content')[idx].text
    review_dict['Recommended'] = soup.find_all('div',{'class':"review-stats"})[idx].find_all('tr')[-1].find_all('td')[-1].text
        
    # Type of Traveller
    try:
        review.find('td',{'class':'review-rating-header type_of_traveller'}).text is not None
        review_dict['traveller_type'] = soup.find_all('td',{'class':'review-rating-header type_of_traveller'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['traveller_type'] = np.nan
    
    # Seat type
    try:
        review.find('td',{'class':'review-rating-header cabin_flown'}).text is not None
        review_dict['seat_type'] = soup.find_all('td',{'class':'review-rating-header cabin_flown'})[idx].fetchNextSiblings()[0].text
    
    except:
        review_dict['seat_type'] = np.nan
    
    
    # Append dictionary into a list
    final_list.append(review_dict)

# Create DataFrame
df = pd.DataFrame(final_list)
df['airline'] = 'jetstar airways'

# Save to CSV
df.to_csv('Data/jetstar_airways.csv',index=False)

# %%
# Sanity check
df
# Out:
#    Value For Money Ground Service Cabin Staff Service Seat Comfort  \
# 0                1              1                   1            1
# 1                1            NaN                 NaN          NaN
# 2                1              1                   1            1
# 3                1              1                   1            1
# 4                1              1                 NaN          NaN
# ..             ...            ...                 ...          ...
# 95               1              1                 NaN          NaN
# 96               1              1                   1            1
# 97               3              4                   3            2
# 98               1              1                   2            1
# 99               1              1                   1            1
#
#             Author        Date Overall_rating  \
# 0      Saul Geffen  2020-05-06              1
# 1      E Marcerios  2020-05-05              1
# 2   Chris Pokrzywa  2020-04-27              1
# 3     Caryn Jervis  2020-04-21              1
# 4         A Gurten  2020-04-15              1
# ..             ...         ...            ...
# 95  Paul Simonides  2019-12-08              1
# 96      Victor Hew  2019-12-07              1
# 97     Ian Fleming  2019-12-06              2
# 98           J Ryd  2019-12-03              1
# 99       D Varunic  2019-12-02              1
#
#                                          text_content Recommended  \
# 0   Not Verified |  Brisbane to Melbourne. Just li...          no
# 1   ✅ Trip Verified |  My friend and I were travel...          no
# 2   ✅ Trip Verified | I'm absolutely appalled Jets...          no
# 3   ✅ Trip Verified | Extremely poor customer serv...          no
# 4   ✅ Trip Verified |  I am very disappointed with...          no
# ..                                                ...         ...
# 95  Not Verified |  Adelaide to Sydney. I've been ...          no
# 96  ✅ Trip Verified |  Sydney to Melbourne. If the...          no
# 97  ✅ Trip Verified |  Newcastle to Melbourne. Boo...          no
# 98  Not Verified |  Queenstown to Sydney. My fligh...          no
# 99  ✅ Trip Verified |  Sunshine Coast to Sydney. T...          no
#
#     traveller_type       seat_type Wifi & Connectivity Inflight Entertainment  \
# 0     Solo Leisure   Economy Class                 NaN                    NaN
# 1   Couple Leisure   Economy Class                 NaN                    NaN
# 2   Couple Leisure  Business Class                 NaN                    NaN
# 3     Solo Leisure   Economy Class                 NaN                    NaN
# 4   Family Leisure   Economy Class                 NaN                    NaN
# ..             ...             ...                 ...                    ...
# 95  Family Leisure   Economy Class                 NaN                    NaN
# 96    Solo Leisure   Economy Class                 NaN                    NaN
# 97  Couple Leisure   Economy Class                 NaN                    NaN
# 98    Solo Leisure   Economy Class                   1                      1
# 99        Business   Economy Class                   1                      1
#
#    Food & Beverages          airline
# 0               NaN  jetstar airways
# 1               NaN  jetstar airways
# 2               NaN  jetstar airways
# 3               NaN  jetstar airways
# 4               NaN  jetstar airways
# ..              ...              ...
# 95              NaN  jetstar airways
# 96              NaN  jetstar airways
# 97              NaN  jetstar airways
# 98                1  jetstar airways
# 99                1  jetstar airways
#
# [100 rows x 15 columns]
