# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %matplotlib inline

# %%
df = pd.read_csv('Data/airline_final.csv',parse_dates=['date'],keep_default_na=False)

# %%
df.tail()
# Out:
#             airline_name      author       date  \
# 80515  xl airways france    r dorlen 2017-09-02
# 80516  xl airways france    m lazado 2017-08-31
# 80517  xl airways france    p layvar 2017-08-11
# 80518  xl airways france  h speccisi 2017-08-11
# 80519  xl airways france    m ramiro 2017-07-31
#
#                                                  content  type_traveller  \
# 80515    miami to paris. so reading most of the other...    solo leisure
# 80516    paris to los angeles. i was skeptical about ...  couple leisure
# 80517    san francisco to paris cdg. worst experience...  family leisure
# 80518    paris to san francisco, the aircraft was dir...  couple leisure
# 80519    san francisco to paris. i was a bit nervous ...  couple leisure
#
#          cabin_flown  overall_rating  seat_comfort_rating  cabin_staff_rating  \
# 80515  economy class               7                    3                   5
# 80516  economy class              10                    3                   5
# 80517  economy class               1                    1                   5
# 80518  economy class               3                    1                   3
# 80519  economy class              10                    3                   5
#
#        food_beverages_rating  inflight_entertainment_rating  \
# 80515                      4                              1
# 80516                      5                              5
# 80517                      1                              1
# 80518                      1                              1
# 80519                      4                              3
#
#        ground_service_rating  value_money_rating  recommended  \
# 80515                      3                   5            1
# 80516                      5                   5            1
# 80517                      1                   1            0
# 80518                      4                   2            0
# 80519                      5                   5            1
#
#                           hubs country
# 80515  paris charles de gaulle  france
# 80516  paris charles de gaulle  france
# 80517  paris charles de gaulle  france
# 80518  paris charles de gaulle  france
# 80519  paris charles de gaulle  france

# %%
# Check shape
df.shape
# Out:
# (80520, 16)

# %%
# Check null
df.isnull().sum()
# Out:
# airline_name                     0
# author                           0
# date                             0
# content                          0
# type_traveller                   0
# cabin_flown                      0
# overall_rating                   0
# seat_comfort_rating              0
# cabin_staff_rating               0
# food_beverages_rating            0
# inflight_entertainment_rating    0
# ground_service_rating            0
# value_money_rating               0
# recommended                      0
# hubs                             0
# country                          0
# dtype: int64

# %% [markdown]
# ## Item-Based Collaborative Filtering
#
# - The Airline will be the index
# - The Author will be the column
# - The Overall Rating will be the Value

# %% [markdown]
# ### Create Pivot Table

# %%
# Using Pivot Table
pivot = pd.pivot_table(df,index="airline_name",columns="author",values="overall_rating")
pivot.head()
# Out:
# author                      moam ben-shalom   -  - t mcdonough  a aamir  \
# airline_name
# adria airways                           NaN NaN            NaN      NaN
# aegean airlines                         NaN NaN            NaN      NaN
# aer lingus                              NaN NaN            NaN      NaN
# aerocaribbean                           NaN NaN            NaN      NaN
# aeroflot russian airlines               NaN NaN            NaN      NaN
#
# author                     a abbado  a abdelbadee  a abdo  a abril  a acosta  \
# airline_name
# adria airways                   NaN           NaN     NaN      NaN       NaN
# aegean airlines                 NaN           NaN     NaN      NaN       NaN
# aer lingus                      NaN           NaN     NaN      NaN       NaN
# aerocaribbean                   NaN           NaN     NaN      NaN       NaN
# aeroflot russian airlines       NaN           NaN     NaN      NaN       NaN
#
# author                     a adam  ...  zunyi xie  zuozhou li  zuqi zhao  \
# airline_name                       ...
# adria airways                 NaN  ...        NaN         NaN        NaN
# aegean airlines               NaN  ...        NaN         NaN        NaN
# aer lingus                    NaN  ...        NaN         NaN        NaN
# aerocaribbean                 NaN  ...        NaN         NaN        NaN
# aeroflot russian airlines     NaN  ...        NaN         NaN        NaN
#
# author                     zust roland  zuzana daridova  zvi rosen  zy cao  \
# airline_name
# adria airways                      NaN              NaN        NaN     NaN
# aegean airlines                    NaN              NaN        NaN     NaN
# aer lingus                         NaN              NaN        NaN     NaN
# aerocaribbean                      NaN              NaN        NaN     NaN
# aeroflot russian airlines          NaN              NaN        4.0     NaN
#
# author                     ã–mer yazä±cä±  ã–zgã¼n gã¼ndoäÿdu  \
# airline_name
# adria airways                         NaN                 NaN
# aegean airlines                       NaN                 NaN
# aer lingus                            NaN                 NaN
# aerocaribbean                         NaN                 NaN
# aeroflot russian airlines             NaN                 NaN
#
# author                     ã‰amonn mac an bheatha
# airline_name
# adria airways                                 NaN
# aegean airlines                               NaN
# aer lingus                                    NaN
# aerocaribbean                                 NaN
# aeroflot russian airlines                     NaN
#
# [5 rows x 55019 columns]

# %%
pivot.shape
# Out:
# (371, 55019)

# %% [markdown]
# ### Create Sparse Matrix

# %%
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))
print(sparse_pivot)
# Out:
#   (0, 840)	5.0
#   (0, 903)	2.0
#   (0, 1453)	9.0
#   (0, 1847)	5.0
#   (0, 2763)	8.333333333333334
#   (0, 3359)	8.0
#   (0, 3531)	7.0
#   (0, 4510)	5.0
#   (0, 4527)	9.0
#   (0, 4739)	1.0
#   (0, 4984)	3.0
#   (0, 5545)	2.0
#   (0, 6489)	8.0
#   (0, 8290)	3.0
#   (0, 10555)	1.0
#   (0, 11133)	7.0
#   (0, 11415)	3.0
#   (0, 11477)	1.0
#   (0, 11674)	1.0
#   (0, 13949)	9.0
#   (0, 13961)	9.0
#   (0, 17373)	3.0
#   (0, 17982)	10.0
#   (0, 17984)	9.333333333333334
#   (0, 18095)	1.0
#   :	:
#   (367, 49396)	1.0
#   (367, 50503)	9.0
#   (367, 51615)	8.0
#   (367, 53143)	1.0
#   (367, 54625)	2.0
#   (368, 5723)	6.0
#   (368, 24092)	6.0
#   (369, 24736)	10.0
#   (369, 43845)	7.0
#   (369, 44284)	9.0
#   (370, 1962)	5.0
#   (370, 2027)	6.0
#   (370, 6281)	5.0
#   (370, 15493)	4.0
#   (370, 15628)	3.0
#   (370, 20808)	4.0
#   (370, 21130)	5.0
#   (370, 23841)	4.0
#   (370, 31766)	6.0
#   (370, 38505)	2.0
#   (370, 40387)	5.0
#   (370, 44982)	7.0
#   (370, 46714)	7.0
#   (370, 47665)	2.0
#   (370, 54789)	1.0

# %% [markdown]
# ### Cosine Similarity

# %%
recommender = pairwise_distances(sparse_pivot,metric='cosine')

# %%
recommender.shape
# Out:
# (371, 371)

# %% [markdown]
# ### Create Distance Dataframe

# %%
recommender_df = pd.DataFrame(recommender,columns=pivot.index,index=pivot.index)
recommender_df.head()
# Out:
# airline_name               adria airways  aegean airlines  aer lingus  \
# airline_name
# adria airways                   0.000000         0.949077    0.987885
# aegean airlines                 0.949077         0.000000    0.982295
# aer lingus                      0.987885         0.982295    0.000000
# aerocaribbean                   1.000000         1.000000    1.000000
# aeroflot russian airlines       0.978923         0.985923    0.993144
#
# airline_name               aerocaribbean  aeroflot russian airlines  \
# airline_name
# adria airways                    1.00000                   0.978923
# aegean airlines                  1.00000                   0.985923
# aer lingus                       1.00000                   0.993144
# aerocaribbean                    0.00000                   0.946090
# aeroflot russian airlines        0.94609                   0.000000
#
# airline_name               aerogal aerolineas galapagos  \
# airline_name
# adria airways                                       1.0
# aegean airlines                                     1.0
# aer lingus                                          1.0
# aerocaribbean                                       1.0
# aeroflot russian airlines                           1.0
#
# airline_name               aerolineas argentinas  aeromexico  aerosur  \
# airline_name
# adria airways                           0.983616    0.978396      1.0
# aegean airlines                         0.988810    0.986616      1.0
# aer lingus                              0.993086    0.995912      1.0
# aerocaribbean                           1.000000    1.000000      1.0
# aeroflot russian airlines               0.994266    0.992623      1.0
#
# airline_name               afriqiyah airways  ...  westjet  wideroe  \
# airline_name                                  ...
# adria airways                            1.0  ...      1.0      1.0
# aegean airlines                          1.0  ...      1.0      1.0
# aer lingus                               1.0  ...      1.0      1.0
# aerocaribbean                            1.0  ...      1.0      1.0
# aeroflot russian airlines                1.0  ...      1.0      1.0
#
# airline_name               wings air  wizz air   wow air  xiamen airlines  \
# airline_name
# adria airways                    1.0  0.988961  1.000000         1.000000
# aegean airlines                  1.0  0.989405  0.984729         0.988700
# aer lingus                       1.0  0.980754  0.998471         0.993536
# aerocaribbean                    1.0  1.000000  1.000000         1.000000
# aeroflot russian airlines        1.0  0.990583  0.998587         0.970777
#
# airline_name               xl airways france  yakutia airlines  \
# airline_name
# adria airways                       1.000000               1.0
# aegean airlines                     1.000000               1.0
# aer lingus                          1.000000               1.0
# aerocaribbean                       1.000000               1.0
# aeroflot russian airlines           0.986437               1.0
#
# airline_name               yangon airways  yemenia
# airline_name
# adria airways                         1.0      1.0
# aegean airlines                       1.0      1.0
# aer lingus                            1.0      1.0
# aerocaribbean                         1.0      1.0
# aeroflot russian airlines             1.0      1.0
#
# [5 rows x 371 columns]

# %% [markdown]
# ### Evaluate Recommender Performance

# %%
df.head()
# Out:
#     airline_name        author       date  \
# 0  adria airways         d ito 2015-04-10
# 1  adria airways  ron kuhlmann 2015-01-05
# 2  adria airways       e albin 2014-09-14
# 3  adria airways  tercon bojan 2014-09-06
# 4  adria airways       l james 2014-06-16
#
#                                              content type_traveller  \
# 0  outbound flight fra/prn a319. 2 hours 10 min f...             NA
# 1  two short hops zrh-lju and lju-vie. very fast ...             NA
# 2  flew zurich-ljubljana on jp365 newish crj900. ...             NA
# 3  adria serves this 100 min flight from ljubljan...             NA
# 4  waw-skj economy. no free snacks or drinks on t...             NA
#
#       cabin_flown  overall_rating  seat_comfort_rating  cabin_staff_rating  \
# 0         economy               7                    4                   4
# 1  business class              10                    4                   5
# 2         economy               9                    5                   5
# 3  business class               8                    4                   4
# 4         economy               4                    4                   2
#
#    food_beverages_rating  inflight_entertainment_rating  \
# 0                      4                              0
# 1                      4                              1
# 2                      4                              0
# 3                      3                              1
# 4                      1                              2
#
#    ground_service_rating  value_money_rating  recommended  \
# 0                      4                   4            1
# 1                      5                   5            1
# 2                      5                   5            1
# 3                      4                   4            1
# 4                      2                   2            0
#
#                      hubs country
# 0  pristina international  kosovo
# 1  pristina international  kosovo
# 2  pristina international  kosovo
# 3  pristina international  kosovo
# 4  pristina international  kosovo

# %%
search = "singapore airline"

airlines = (df.loc[df['airline_name'].str.contains(search),'airline_name']).unique()

for airline in airlines:
    print(airline)
    print('Average overall rating: ',pivot.loc[airline,:].mean())
    print('Number of review: ',pivot.loc[airline,:].count())
    
    print('')
    print('5 recommended airline: ')
    recommended_airline = recommender_df[airline].sort_values()[1:6]
    print(recommended_airline)
    print('')
    print('************************')
# Out:
# singapore airlines
# Average overall rating:  7.334841357926819
# Number of review:  901
#
# 5 recommended airline:
# airline_name
# silkair                   0.876184
# cathay pacific airways    0.934092
# garuda indonesia          0.935895
# qantas airways            0.936182
# thai airways              0.940914
# Name: singapore airlines, dtype: float64
#
# ************************

# %%
# SVD = user to airlines
# U = 'User to Concept'
# E = 'Str of concept'
# Vt = 'Movie to Concept'
'movie', 'user','concept'

# %% [markdown]
# ## Content-based filtering

# %%
# Make a copy of df
content_df = df.copy()

# %%
content_df.head()
# Out:
#     airline_name        author       date  \
# 0  adria airways         d ito 2015-04-10
# 1  adria airways  ron kuhlmann 2015-01-05
# 2  adria airways       e albin 2014-09-14
# 3  adria airways  tercon bojan 2014-09-06
# 4  adria airways       l james 2014-06-16
#
#                                              content type_traveller  \
# 0  outbound flight fra/prn a319. 2 hours 10 min f...             NA
# 1  two short hops zrh-lju and lju-vie. very fast ...             NA
# 2  flew zurich-ljubljana on jp365 newish crj900. ...             NA
# 3  adria serves this 100 min flight from ljubljan...             NA
# 4  waw-skj economy. no free snacks or drinks on t...             NA
#
#       cabin_flown  overall_rating  seat_comfort_rating  cabin_staff_rating  \
# 0         economy               7                    4                   4
# 1  business class              10                    4                   5
# 2         economy               9                    5                   5
# 3  business class               8                    4                   4
# 4         economy               4                    4                   2
#
#    food_beverages_rating  inflight_entertainment_rating  \
# 0                      4                              0
# 1                      4                              1
# 2                      4                              0
# 3                      3                              1
# 4                      1                              2
#
#    ground_service_rating  value_money_rating  recommended  \
# 0                      4                   4            1
# 1                      5                   5            1
# 2                      5                   5            1
# 3                      4                   4            1
# 4                      2                   2            0
#
#                      hubs country
# 0  pristina international  kosovo
# 1  pristina international  kosovo
# 2  pristina international  kosovo
# 3  pristina international  kosovo
# 4  pristina international  kosovo

# %%
content_df.shape
# Out:
# (80520, 16)

# %%
# Out:
# heathrow                                   3524
# fort lauderdale hollywood international    3032
# o'hare international                       2921
# dallas/fort worth international            2918
# dublin airport                             2498
#                                            ...
# ted stevens anchorage international           1
# rosario islas malvinas international          1
# halifax stanfield international               1
# nantes atlantique                             1
# dushanbe international                        1
# Name: hubs, Length: 282, dtype: int64
