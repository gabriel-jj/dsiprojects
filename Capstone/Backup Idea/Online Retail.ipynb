# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances

# %matplotlib inline

# %%
df = pd.read_csv('Data/Online_Retail.csv',parse_dates=['InvoiceDate'])

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847
# JUMBO BAG RED RETROSPOT               47363
# ASSORTED COLOUR BIRD ORNAMENT         36381
# POPCORN HOLDER                        36334
# PACK OF 72 RETROSPOT CAKE CASES       36039
# WHITE HANGING HEART T-LIGHT HOLDER    35317
# RABBIT NIGHT LIGHT                    30680
# MINI PAINT SET VINTAGE                26437
# PACK OF 12 LONDON TISSUES             26315
# PACK OF 60 PINK PAISLEY CAKE CASES    24753
# Name: Quantity, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ## Duplicated Values
# Not dropping duplicated values as the Customer might separate their purchases on the same items.

# %%
df.duplicated().sum()
# Out:
# 5268

# %% [markdown]
# ## Null Values

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.dropna(subset=['CustomerID'], inplace=True)

# %%
df.shape
# Out:
# (406829, 8)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# ## InvoiceNo
# Did an investigation to the InvoiceNo to see if there's a need to convert to int.

# %%
# Check the InvoiceNo for non-number
df[df['InvoiceNo'].str.contains(r'\D')].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %% [markdown]
# ## Quantity
# The quantity sold contains negative numbers which might be due to human error. An absolute is applied to the quantity column to change the negative value to positive

# %%
df['Quantity'] = df['Quantity'].abs()

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Customer ID
# Convert the customer ID to a whole number.

# %%
df.CustomerID = df.CustomerID.astype(int)

# %% [markdown]
# ## Rename Columns
# Renaming column Description to Item

# %%
df.rename(columns={'Description':'Item'},inplace=True)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                                 Item  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom

# %% [markdown]
# ## Create Total Spent

# %%
df['Total Spent'] = df['Quantity'] * df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                                 Item  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total Spent
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34

# %% [markdown]
# ## Item-Based Collaborative Filtering
# - The Item will be the index
# - The CustomerID will be the column
# - The UnitPrice will be the value

# %%
df.shape
# Out:
# (406829, 9)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                                 Item  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total Spent
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34

# %%
# Using Pivot Table
pivot = pd.pivot_table(df,index='Item',columns='CustomerID',values='UnitPrice')
pivot.head()
# Out:
# CustomerID                      12346  12347  12348  12349  12350  12352  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES    NaN    NaN    NaN    NaN    NaN    NaN
#  50'S CHRISTMAS GIFT BAG LARGE    NaN    NaN    NaN    NaN    NaN    NaN
#  DOLLY GIRL BEAKER                NaN    NaN    NaN    NaN    NaN    NaN
#  I LOVE LONDON MINI BACKPACK      NaN    NaN    NaN    NaN    NaN    NaN
#  I LOVE LONDON MINI RUCKSACK      NaN    NaN    NaN    NaN    NaN    NaN
#
# CustomerID                      12353  12354  12355  12356  ...  18273  18274  \
# Item                                                        ...
#  4 PURPLE FLOCK DINNER CANDLES    NaN    NaN    NaN    NaN  ...    NaN    NaN
#  50'S CHRISTMAS GIFT BAG LARGE    NaN    NaN    NaN    NaN  ...    NaN    NaN
#  DOLLY GIRL BEAKER                NaN    NaN    NaN    NaN  ...    NaN    NaN
#  I LOVE LONDON MINI BACKPACK      NaN    NaN    NaN    NaN  ...    NaN    NaN
#  I LOVE LONDON MINI RUCKSACK      NaN    NaN    NaN    NaN  ...    NaN    NaN
#
# CustomerID                      18276  18277  18278  18280  18281  18282  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES    NaN    NaN    NaN    NaN    NaN    NaN
#  50'S CHRISTMAS GIFT BAG LARGE    NaN    NaN    NaN    NaN    NaN    NaN
#  DOLLY GIRL BEAKER                NaN    NaN    NaN    NaN    NaN    NaN
#  I LOVE LONDON MINI BACKPACK      NaN    NaN    NaN    NaN    NaN    NaN
#  I LOVE LONDON MINI RUCKSACK      NaN    NaN    NaN    NaN    NaN    NaN
#
# CustomerID                      18283  18287
# Item
#  4 PURPLE FLOCK DINNER CANDLES    NaN    NaN
#  50'S CHRISTMAS GIFT BAG LARGE    NaN    NaN
#  DOLLY GIRL BEAKER                NaN    NaN
#  I LOVE LONDON MINI BACKPACK      NaN    NaN
#  I LOVE LONDON MINI RUCKSACK      NaN    NaN
#
# [5 rows x 4372 columns]

# %%
pivot.shape
# Out:
# (3896, 4372)

# %%
pivot.index.value_counts().nlargest(10)
# Out:
# SMALL HAMMERED SILVER CANDLEPOT       1
# PAPER CHAIN KIT EMPIRE                1
# SET OF 10 LED DOLLY LIGHTS            1
# GREEN SWEETHEART BRACELET             1
# INFLATABLE POLITICAL GLOBE            1
# HOME GARLAND PAINTED ZINC             1
# PINK ACRYLIC JEWEL SNOWFLAKE          1
# BULL DOG BOTTLE OPENER                1
# GLASS JAR DIGESTIVE BISCUITS          1
# PACK OF 60 PINK PAISLEY CAKE CASES    1
# Name: Item, dtype: int64

# %% [markdown]
# ## Create Sparse Matrix

# %%
sparse_pivot = sparse.csr_matrix(pivot.fillna(0))
print(sparse_pivot)
# Out:
#   (0, 462)	2.55
#   (0, 465)	2.55
#   (0, 476)	2.55
#   (0, 1192)	0.79
#   (0, 1282)	0.79
#   (0, 1292)	2.55
#   (0, 1345)	2.55
#   (0, 1762)	2.55
#   (0, 1958)	2.55
#   (0, 2033)	2.55
#   (0, 2306)	2.55
#   (0, 2359)	2.55
#   (0, 2360)	2.55
#   (0, 2424)	0.79
#   (0, 2612)	2.55
#   (0, 2646)	2.55
#   (0, 2702)	2.55
#   (0, 2914)	2.55
#   (0, 3272)	2.55
#   (0, 3279)	0.79
#   (0, 3493)	2.55
#   (0, 3636)	2.55
#   (0, 3656)	1.67
#   (0, 3675)	2.55
#   (0, 4000)	2.55
#   :	:
#   (3894, 1752)	10.4
#   (3894, 2725)	10.4
#   (3894, 2821)	3.95
#   (3894, 3427)	10.4
#   (3894, 3757)	3.95
#   (3894, 3900)	10.4
#   (3894, 3950)	10.4
#   (3895, 515)	3.75
#   (3895, 657)	3.75
#   (3895, 802)	3.75
#   (3895, 905)	3.75
#   (3895, 1295)	3.29
#   (3895, 1447)	3.29
#   (3895, 1751)	3.75
#   (3895, 1895)	1.25
#   (3895, 2291)	3.75
#   (3895, 2313)	3.75
#   (3895, 2520)	3.75
#   (3895, 3252)	3.75
#   (3895, 3639)	3.75
#   (3895, 3818)	3.75
#   (3895, 3950)	3.75
#   (3895, 4024)	3.75
#   (3895, 4037)	1.25
#   (3895, 4042)	3.75

# %% [markdown]
# ## Cosine Similarity

# %%
recommender = pairwise_distances(sparse_pivot,metric='cosine')

# %%
recommender.shape
# Out:
# (3896, 3896)

# %% [markdown]
# ## Create Distance DataFrame

# %%
recommender_df = pd.DataFrame(recommender,columns=pivot.index,index=pivot.index)
recommender_df.head()
# Out:
# Item                             4 PURPLE FLOCK DINNER CANDLES  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                        0.000000
#  50'S CHRISTMAS GIFT BAG LARGE                        1.000000
#  DOLLY GIRL BEAKER                                    0.961480
#  I LOVE LONDON MINI BACKPACK                          0.974602
#  I LOVE LONDON MINI RUCKSACK                          1.000000
#
# Item                             50'S CHRISTMAS GIFT BAG LARGE  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                        1.000000
#  50'S CHRISTMAS GIFT BAG LARGE                        0.000000
#  DOLLY GIRL BEAKER                                    0.941795
#  I LOVE LONDON MINI BACKPACK                          0.961623
#  I LOVE LONDON MINI RUCKSACK                          1.000000
#
# Item                             DOLLY GIRL BEAKER  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES            0.961480
#  50'S CHRISTMAS GIFT BAG LARGE            0.941795
#  DOLLY GIRL BEAKER                        0.000000
#  I LOVE LONDON MINI BACKPACK              0.858277
#  I LOVE LONDON MINI RUCKSACK              0.911120
#
# Item                             I LOVE LONDON MINI BACKPACK  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                      0.974602
#  50'S CHRISTMAS GIFT BAG LARGE                      0.961623
#  DOLLY GIRL BEAKER                                  0.858277
#  I LOVE LONDON MINI BACKPACK                        0.000000
#  I LOVE LONDON MINI RUCKSACK                        0.881161
#
# Item                             I LOVE LONDON MINI RUCKSACK  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                      1.000000
#  50'S CHRISTMAS GIFT BAG LARGE                      1.000000
#  DOLLY GIRL BEAKER                                  0.911120
#  I LOVE LONDON MINI BACKPACK                        0.881161
#  I LOVE LONDON MINI RUCKSACK                        0.000000
#
# Item                             NINE DRAWER OFFICE TIDY  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                  1.000000
#  50'S CHRISTMAS GIFT BAG LARGE                  0.963494
#  DOLLY GIRL BEAKER                              0.962571
#  I LOVE LONDON MINI BACKPACK                    0.950642
#  I LOVE LONDON MINI RUCKSACK                    1.000000
#
# Item                             OVAL WALL MIRROR DIAMANTE   \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                     0.990469
#  50'S CHRISTMAS GIFT BAG LARGE                     0.938020
#  DOLLY GIRL BEAKER                                 0.952339
#  I LOVE LONDON MINI BACKPACK                       0.958100
#  I LOVE LONDON MINI RUCKSACK                       1.000000
#
# Item                             RED SPOT GIFT BAG LARGE  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                  1.000000
#  50'S CHRISTMAS GIFT BAG LARGE                  0.669694
#  DOLLY GIRL BEAKER                              0.933795
#  I LOVE LONDON MINI BACKPACK                    0.956348
#  I LOVE LONDON MINI RUCKSACK                    1.000000
#
# Item                             SET 2 TEA TOWELS I LOVE LONDON   \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                          0.967195
#  50'S CHRISTMAS GIFT BAG LARGE                          0.968938
#  DOLLY GIRL BEAKER                                      0.939025
#  I LOVE LONDON MINI BACKPACK                            0.873457
#  I LOVE LONDON MINI RUCKSACK                            1.000000
#
# Item                             SPACEBOY BABY GIFT SET  ...  \
# Item                                                     ...
#  4 PURPLE FLOCK DINNER CANDLES                 0.983386  ...
#  50'S CHRISTMAS GIFT BAG LARGE                 0.914613  ...
#  DOLLY GIRL BEAKER                             0.801249  ...
#  I LOVE LONDON MINI BACKPACK                   0.888670  ...
#  I LOVE LONDON MINI RUCKSACK                   0.913972  ...
#
# Item                            ZINC STAR T-LIGHT HOLDER   \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                        1.0
#  50'S CHRISTMAS GIFT BAG LARGE                        1.0
#  DOLLY GIRL BEAKER                                    1.0
#  I LOVE LONDON MINI BACKPACK                          1.0
#  I LOVE LONDON MINI RUCKSACK                          1.0
#
# Item                            ZINC SWEETHEART SOAP DISH  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                   0.946308
#  50'S CHRISTMAS GIFT BAG LARGE                   0.964377
#  DOLLY GIRL BEAKER                               0.972273
#  I LOVE LONDON MINI BACKPACK                     0.951835
#  I LOVE LONDON MINI RUCKSACK                     1.000000
#
# Item                            ZINC SWEETHEART WIRE LETTER RACK  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                          0.953761
#  50'S CHRISTMAS GIFT BAG LARGE                          0.953421
#  DOLLY GIRL BEAKER                                      0.952243
#  I LOVE LONDON MINI BACKPACK                            0.952767
#  I LOVE LONDON MINI RUCKSACK                            1.000000
#
# Item                            ZINC T-LIGHT HOLDER STAR LARGE  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                        0.965995
#  50'S CHRISTMAS GIFT BAG LARGE                        0.965746
#  DOLLY GIRL BEAKER                                    0.914470
#  I LOVE LONDON MINI BACKPACK                          0.968143
#  I LOVE LONDON MINI RUCKSACK                          0.926788
#
# Item                            ZINC T-LIGHT HOLDER STARS LARGE  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                              1.0
#  50'S CHRISTMAS GIFT BAG LARGE                              1.0
#  DOLLY GIRL BEAKER                                          1.0
#  I LOVE LONDON MINI BACKPACK                                1.0
#  I LOVE LONDON MINI RUCKSACK                                1.0
#
# Item                            ZINC T-LIGHT HOLDER STARS SMALL  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                         0.971305
#  50'S CHRISTMAS GIFT BAG LARGE                         0.906057
#  DOLLY GIRL BEAKER                                     0.905362
#  I LOVE LONDON MINI BACKPACK                           0.963030
#  I LOVE LONDON MINI RUCKSACK                           0.935554
#
# Item                            ZINC TOP  2 DOOR WOODEN SHELF   \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                             1.0
#  50'S CHRISTMAS GIFT BAG LARGE                             1.0
#  DOLLY GIRL BEAKER                                         1.0
#  I LOVE LONDON MINI BACKPACK                               1.0
#  I LOVE LONDON MINI RUCKSACK                               1.0
#
# Item                            ZINC WILLIE WINKIE  CANDLE STICK  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                          0.945861
#  50'S CHRISTMAS GIFT BAG LARGE                          0.967045
#  DOLLY GIRL BEAKER                                      0.968282
#  I LOVE LONDON MINI BACKPACK                            0.946918
#  I LOVE LONDON MINI RUCKSACK                            0.928255
#
# Item                            ZINC WIRE KITCHEN ORGANISER  \
# Item
#  4 PURPLE FLOCK DINNER CANDLES                     1.000000
#  50'S CHRISTMAS GIFT BAG LARGE                     1.000000
#  DOLLY GIRL BEAKER                                 0.985544
#  I LOVE LONDON MINI BACKPACK                       1.000000
#  I LOVE LONDON MINI RUCKSACK                       1.000000
#
# Item                            ZINC WIRE SWEETHEART LETTER TRAY
# Item
#  4 PURPLE FLOCK DINNER CANDLES                          0.951356
#  50'S CHRISTMAS GIFT BAG LARGE                          0.991833
#  DOLLY GIRL BEAKER                                      0.941386
#  I LOVE LONDON MINI BACKPACK                            0.933747
#  I LOVE LONDON MINI RUCKSACK                            1.000000
#
# [5 rows x 3896 columns]

# %% [markdown]
# ## Evaluate recommender performance

# %%
search = "CHILDREN'S APRON DOLLY GIRL"

price = (df.loc[df['Item'].str.contains(search),'Item']).unique()

for item in price:
    print(item)
    print('Average Price: ', pivot.loc[item,:].mean())
    print('Number of Item: ', pivot.loc[item,:].count())
    
    print('')
    print('10 recommended items: ')
    recommended_item = recommender_df[item].sort_values()[1:11]
    print(recommended_item)
    print('')
    print('***********************')
# Out:
# CHILDREN'S APRON DOLLY GIRL
# Average Price:  2.0985863874345605
# Number of Item:  191
#
# 10 recommended items:
# Item
# CHILDRENS APRON SPACEBOY DESIGN    0.452217
# LUNCH BAG DOLLY GIRL DESIGN        0.626852
# RETROSPOT CHILDRENS APRON          0.634272
# PINK FAIRY CAKE CHILDRENS APRON    0.642912
# DOLLY GIRL LUNCH BOX               0.651518
# SPACEBOY LUNCH BOX                 0.670644
# CHILDRENS APRON APPLES DESIGN      0.674141
# LUNCH BAG SPACEBOY DESIGN          0.685596
# DOLLY GIRL MINI BACKPACK           0.686651
# CHARLOTTE BAG DOLLY GIRL DESIGN    0.702261
# Name: CHILDREN'S APRON DOLLY GIRL , dtype: float64
#
# ***********************

# %% [markdown]
# ## User-Based Collaborative Filtering
# - The CustomerID will be the index
# - The Item will be the column
# - The Quantity will be the value
#
# Usually wholeseller will have problem deciding how much quantity they should be getting for each of the items. Hence we will recommend the user based on the quantity bought by other similar users as a reference.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                                 Item  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total Spent
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom        20.34

# %%
# Using pivot table
id_pivot = pd.pivot_table(df,index='CustomerID',columns='Item',values='Quantity')
id_pivot.head()
# Out:
# Item         4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# CustomerID
# 12346                                  NaN                             NaN
# 12347                                  NaN                             NaN
# 12348                                  NaN                             NaN
# 12349                                  NaN                             NaN
# 12350                                  NaN                             NaN
#
# Item         DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# CustomerID
# 12346                      NaN                           NaN
# 12347                      NaN                           NaN
# 12348                      NaN                           NaN
# 12349                      NaN                           NaN
# 12350                      NaN                           NaN
#
# Item         I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# CustomerID
# 12346                                NaN                       NaN
# 12347                                NaN                       NaN
# 12348                                NaN                       NaN
# 12349                                NaN                       NaN
# 12350                                NaN                       NaN
#
# Item         OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# CustomerID
# 12346                               NaN                       NaN
# 12347                               NaN                       NaN
# 12348                               NaN                       NaN
# 12349                               NaN                       NaN
# 12350                               NaN                       NaN
#
# Item         SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# CustomerID                                                             ...
# 12346                                    NaN                      NaN  ...
# 12347                                    NaN                      NaN  ...
# 12348                                    NaN                      NaN  ...
# 12349                                    NaN                      NaN  ...
# 12350                                    NaN                      NaN  ...
#
# Item        ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# CustomerID
# 12346                             NaN                        NaN
# 12347                             NaN                        NaN
# 12348                             NaN                        NaN
# 12349                             NaN                        NaN
# 12350                             NaN                        NaN
#
# Item        ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# CustomerID
# 12346                                    NaN                             NaN
# 12347                                    NaN                             NaN
# 12348                                    NaN                             NaN
# 12349                                    NaN                             NaN
# 12350                                    NaN                             NaN
#
# Item        ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# CustomerID
# 12346                                   NaN                              NaN
# 12347                                   NaN                              NaN
# 12348                                   NaN                              NaN
# 12349                                   NaN                              NaN
# 12350                                   NaN                              NaN
#
# Item        ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# CustomerID
# 12346                                  NaN                               NaN
# 12347                                  NaN                               NaN
# 12348                                  NaN                               NaN
# 12349                                  NaN                               NaN
# 12350                                  NaN                               NaN
#
# Item        ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# CustomerID
# 12346                               NaN                               NaN
# 12347                               NaN                               NaN
# 12348                               NaN                               NaN
# 12349                               NaN                               NaN
# 12350                               NaN                               NaN
#
# [5 rows x 3896 columns]

# %%
# Convert to sparse matrix
id_sparse = sparse.csr_matrix(id_pivot.fillna(0))
print(id_sparse)
# Out:
#   (0, 2002)	74215.0
#   (1, 70)	25.2
#   (1, 72)	12.0
#   (1, 73)	12.0
#   (1, 109)	24.0
#   (1, 113)	24.0
#   (1, 136)	4.666666666666667
#   (1, 137)	5.333333333333333
#   (1, 138)	4.0
#   (1, 139)	8.0
#   (1, 140)	4.0
#   (1, 142)	5.0
#   (1, 143)	5.333333333333333
#   (1, 145)	4.0
#   (1, 146)	5.333333333333333
#   (1, 147)	7.2
#   (1, 286)	12.0
#   (1, 313)	6.0
#   (1, 324)	12.0
#   (1, 344)	9.0
#   (1, 357)	12.0
#   (1, 366)	30.0
#   (1, 402)	6.0
#   (1, 423)	12.0
#   (1, 452)	24.0
#   :	:
#   (4371, 2464)	12.0
#   (4371, 2480)	4.0
#   (4371, 2486)	6.0
#   (4371, 2916)	40.0
#   (4371, 2917)	24.0
#   (4371, 2977)	4.0
#   (4371, 2997)	36.0
#   (4371, 3027)	24.0
#   (4371, 3068)	24.0
#   (4371, 3095)	6.0
#   (4371, 3143)	48.0
#   (4371, 3145)	18.0
#   (4371, 3154)	48.0
#   (4371, 3159)	24.0
#   (4371, 3163)	30.0
#   (4371, 3166)	24.0
#   (4371, 3207)	24.0
#   (4371, 3284)	12.0
#   (4371, 3285)	12.0
#   (4371, 3301)	12.0
#   (4371, 3354)	12.0
#   (4371, 3368)	30.0
#   (4371, 3369)	12.0
#   (4371, 3410)	24.0
#   (4371, 3501)	12.0

# %%
# Cosine similarity
recommender_id = pairwise_distances(id_sparse,metric='cosine')
recommender_id.shape
# Out:
# (4372, 4372)

# %%
# Create DataFrame
id_df = pd.DataFrame(recommender_id, index=id_pivot.index, columns=id_pivot.index)
id_df.head()
# Out:
# CustomerID  12346     12347     12348     12349     12350     12352  12353  \
# CustomerID
# 12346         0.0  1.000000  1.000000  1.000000  1.000000  1.000000    1.0
# 12347         1.0  0.000000  0.831705  0.985745  0.979653  0.987955    1.0
# 12348         1.0  0.831705  0.000000  0.999946  0.999900  0.999889    1.0
# 12349         1.0  0.985745  0.999946  0.000000  0.969879  0.922464    1.0
# 12350         1.0  0.979653  0.999900  0.969879  0.000000  0.999569    1.0
#
# CustomerID     12354     12355     12356  ...  18273     18274     18276  \
# CustomerID                                ...
# 12346       1.000000  1.000000  1.000000  ...    1.0  1.000000  1.000000
# 12347       0.993560  0.289283  0.925408  ...    1.0  0.999573  0.580469
# 12348       0.986497  0.751867  0.840682  ...    1.0  0.958720  0.860572
# 12349       0.995069  0.999820  0.824997  ...    1.0  0.851934  1.000000
# 12350       1.000000  1.000000  0.998627  ...    1.0  1.000000  1.000000
#
# CustomerID     18277     18278     18280  18281     18282     18283     18287
# CustomerID
# 12346       1.000000  1.000000  1.000000    1.0  1.000000  1.000000  1.000000
# 12347       0.999561  0.995734  0.988565    1.0  0.987953  0.964484  0.890869
# 12348       1.000000  1.000000  1.000000    1.0  1.000000  0.791609  0.928112
# 12349       0.999656  0.984320  1.000000    1.0  0.979033  0.931088  0.991978
# 12350       1.000000  1.000000  1.000000    1.0  1.000000  0.972009  1.000000
#
# [5 rows x 4372 columns]

# %% [markdown]
# ## Recommendation

# %%
id_pivot.head()
# Out:
# Item         4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# CustomerID
# 12346                                  NaN                             NaN
# 12347                                  NaN                             NaN
# 12348                                  NaN                             NaN
# 12349                                  NaN                             NaN
# 12350                                  NaN                             NaN
#
# Item         DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# CustomerID
# 12346                      NaN                           NaN
# 12347                      NaN                           NaN
# 12348                      NaN                           NaN
# 12349                      NaN                           NaN
# 12350                      NaN                           NaN
#
# Item         I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# CustomerID
# 12346                                NaN                       NaN
# 12347                                NaN                       NaN
# 12348                                NaN                       NaN
# 12349                                NaN                       NaN
# 12350                                NaN                       NaN
#
# Item         OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# CustomerID
# 12346                               NaN                       NaN
# 12347                               NaN                       NaN
# 12348                               NaN                       NaN
# 12349                               NaN                       NaN
# 12350                               NaN                       NaN
#
# Item         SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# CustomerID                                                             ...
# 12346                                    NaN                      NaN  ...
# 12347                                    NaN                      NaN  ...
# 12348                                    NaN                      NaN  ...
# 12349                                    NaN                      NaN  ...
# 12350                                    NaN                      NaN  ...
#
# Item        ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# CustomerID
# 12346                             NaN                        NaN
# 12347                             NaN                        NaN
# 12348                             NaN                        NaN
# 12349                             NaN                        NaN
# 12350                             NaN                        NaN
#
# Item        ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# CustomerID
# 12346                                    NaN                             NaN
# 12347                                    NaN                             NaN
# 12348                                    NaN                             NaN
# 12349                                    NaN                             NaN
# 12350                                    NaN                             NaN
#
# Item        ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# CustomerID
# 12346                                   NaN                              NaN
# 12347                                   NaN                              NaN
# 12348                                   NaN                              NaN
# 12349                                   NaN                              NaN
# 12350                                   NaN                              NaN
#
# Item        ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# CustomerID
# 12346                                  NaN                               NaN
# 12347                                  NaN                               NaN
# 12348                                  NaN                               NaN
# 12349                                  NaN                               NaN
# 12350                                  NaN                               NaN
#
# Item        ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# CustomerID
# 12346                               NaN                               NaN
# 12347                               NaN                               NaN
# 12348                               NaN                               NaN
# 12349                               NaN                               NaN
# 12350                               NaN                               NaN
#
# [5 rows x 3896 columns]

# %%
# Get 12348 similarity scores
sim_12348 = id_df[12348].drop(12348)
sim_12348
# Out:
# CustomerID
# 12346    1.000000
# 12347    0.831705
# 12349    0.999946
# 12350    0.999900
# 12352    0.999889
#            ...
# 18280    1.000000
# 18281    1.000000
# 18282    1.000000
# 18283    0.791609
# 18287    0.928112
# Name: 12348, Length: 4371, dtype: float64

# %%
# Filter the top similarity
sim_12348 = sim_12348[sim_12348<0.6]
sim_12348
# Out:
# CustomerID
# 14891    0.529864
# 15232    0.598594
# 17940    0.522354
# Name: 12348, dtype: float64

# %%
# 3. Turn 12348's similarity scores to weights as a %
weights_12348 = sim_12348.values/np.sum(sim_12348.values)
weights_12348
# Out:
# array([0.32097178, 0.36260586, 0.31642236])

# %%
# 4. Get DOLLY GIRL BEAKER quantity
dollygb_quantity = id_pivot[' DOLLY GIRL BEAKER'].drop(12348).loc[sim_12348.index]
dollygb_quantity
# Out:
# CustomerID
# 14891   NaN
# 15232   NaN
# 17940   NaN
# Name:  DOLLY GIRL BEAKER, dtype: float64

# %% [markdown]
# ## Content-based filtering

# %%
# when do ppl buy product
#
